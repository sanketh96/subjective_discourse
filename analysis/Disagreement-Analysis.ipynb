# %%
# x = np.arange(0, 3 * np.pi, 0.1)
# y = np.sin(x)



# y_1, y_2, y_3 = [[0.0,
#   0.005780346820809248,
#   0.023121387283236993,
#   0.10404624277456648,
#   0.2832369942196532,
#   0.5838150289017341],
#  [0.0,
#   0.03608247422680412,
#   0.0979381443298969,
#   0.2422680412371134,
#   0.36082474226804123,
#   0.26288659793814434],
#  [0.0,
#   0.0,
#   0.21212121212121213,
#   0.36363636363636365,
#   0.36363636363636365,
#   0.06060606060606061]]

y_1, y_2, y_3 = [[0.0,
  0.005780346820809248,
  0.023121387283236993,
  0.10404624277456648,
  0.2832369942196532,
  0.5838150289017341],
 [0.0,
  0.03608247422680412,
  0.0979381443298969,
  0.2422680412371134,
  0.36082474226804123,
  0.26288659793814434],
 [0.0,
  0.0,
  0.21212121212121213,
  0.36363636363636365,
  0.36363636363636365,
  0.06060606060606061]]

new_ys = []
for y in [y_1, y_2, y_3]:
    new_y = [round(a*100, 2) for a in y]
    new_ys.append(new_y)
    

y_1, y_2, y_3 = new_ys

x_labels = np.arange(1, len(y_1)+1)
x = x_labels

width = 0.3
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (16,6)) #plt.subplots()
rects1 = ax.bar(x - width, y_1, width, label='All in Agreement')
rects2 = ax.bar(x, y_2, width, label='2-way Disagreement')
rects3 = ax.bar(x + width, y_3, width, label='3-way Disagreement')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('% of examples with exactly n classes accurately predicted')
ax.set_title('Percent of examples with exactly n classes accurately c for Number of Disagreements')
ax.set_xticks(x_labels, x_labels)
ax.set_xlabel('Number of classes accurately predicted - n')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

# plt.plot(x, y)
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install matplotlib

# %%
y_1, y_2, y_3 = [[0.0,
  0.005780346820809248,
  0.023121387283236993,
  0.10404624277456648,
  0.2832369942196532,
  0.5838150289017341],
 [0.0,
  0.03608247422680412,
  0.0979381443298969,
  0.2422680412371134,
  0.36082474226804123,
  0.26288659793814434],
 [0.0,
  0.0,
  0.21212121212121213,
  0.36363636363636365,
  0.36363636363636365,
  0.06060606060606061]]

new_ys = []
for y in [y_1, y_2, y_3]:
    new_y = [round(a*100, 2) for a in y]
    new_ys.append(new_y)

# %%
y_group = [[0.0,
  0.011560693641618497,
  0.03468208092485549,
  0.057803468208092484,
  0.30057803468208094,
  0.5953757225433526],
 [0.005154639175257732,
  0.03608247422680412,
  0.061855670103092786,
  0.26288659793814434,
  0.32989690721649484,
  0.30412371134020616],
 [0.0,
  0.06060606060606061,
  0.09090909090909091,
  0.24242424242424243,
  0.45454545454545453,
  0.15151515151515152]]

new_ys2 = []
for y in y_group:
    new_y = [round(a*100, 2) for a in y]
    new_ys2.append(new_y)

# %%
y_group = [[0.0,
  0.0,
  0.024193548387096774,
  0.12096774193548387,
  0.23387096774193547,
  0.6209677419354839],
 [0.005555555555555556,
  0.013888888888888888,
  0.08611111111111111,
  0.28888888888888886,
  0.2916666666666667,
  0.3138888888888889],
 [0.0,
  0.04411764705882353,
  0.14705882352941177,
  0.16176470588235295,
  0.47058823529411764,
  0.17647058823529413]]

new_ys3 = []
for y in y_group:
    new_y = [round(a*100, 2) for a in y]
    new_ys3.append(new_y)

# %%
y_1, y_2, y_3 = new_ys2

x_labels = np.arange(1, len(y_1)+1)
x = x_labels

width = 0.3
fig, ax = plt.subplots(1,1, figsize = (10,6)) #plt.subplots()
rects1 = ax.bar(x - width, y_1, width, label='All in Agreement')
rects2 = ax.bar(x, y_2, width, label='2-way Disagreement')
rects3 = ax.bar(x + width, y_3, width, label='3-way Disagreement')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Percent of examples with exactly n classes accurately classified for varying Number of Disagreements')
ax.set_xticks(x_labels, x_labels)
ax.set_xlabel('Number of classes accurately classified - n')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

# plt.plot(x, y)
fig.tight_layout()

plt.show()

# %%
y_1, y_2, y_3 = new_ys2

x_labels = np.arange(1, len(y_1)+1)
x = x_labels

width = 0.3
fig, ax = plt.subplots(1,1, figsize = (10,6)) #plt.subplots()
rects1 = ax.bar(x - width, y_1, width, label='All in Agreement')
rects2 = ax.bar(x, y_2, width, label='2-way Disagreement')
rects3 = ax.bar(x + width, y_3, width, label='3-way Disagreement')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Percent of examples with exactly n classes accurately classified for varying Number of Disagreements')
ax.set_xticks(x_labels, x_labels)
ax.set_xlabel('Number of classes accurately classified - n')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

# %%
labels = np.arange(1, 7)
# yesterday_test1_mean = [20, 12, 23]
# yesterday_test2_mean = [21, 14, 25]
# today_test1_mean = [18, 10, 12]
# today_test2_mean = [13, 13, 9]

x = labels #np.arange(len(labels))
width = 0.3

fig = plt.figure(figsize=(15,5))

plt.subplot(121)
plt.title('RoBERTa Hierarchical', fontsize=13)

plt.bar(x - width, new_ys[0], width, label='All in Agreement')
plt.bar(x, new_ys[1], width, label='2-way Disagreement')
plt.bar(x + width, new_ys[2], width, label='3-way Disagreement')
plt.ylabel('Accuracy')
# plt.bar(x-width, new_ys[0], width, label='test1', color=np.array((199, 66, 92))/255)



# plt.bar(x+width/2, yesterday_test2_mean, width, label='test2', color=np.array((240, 140, 58))/255)
plt.xticks(x, labels)


plt.subplot(122)
plt.title('RoBERTa + Annotator Sentiments', fontsize=13)
plt.bar(x - width, new_ys2[0], width, label='All in Agreement')
plt.bar(x, new_ys2[1], width, label='2-way Disagreement')
plt.bar(x + width, new_ys2[2], width, label='3-way Disagreement')
plt.xticks(x, labels)


# plt.bar(x-width/2, today_test1_mean, width, hatch='//', color=np.array((199, 66, 92))/255)
# plt.bar(x+width/2, today_test2_mean, width, color=np.array((240, 140, 58))/255)
# plt.xticks([0,1,2], labels, fontsize=15)

# plt.figlegend(loc='upper right', ncol=1, labelspacing=0.5, fontsize=14, bbox_to_anchor=(1.11, 0.9))
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left')


fig.supxlabel('Number of classes accurately classified')
fig.suptitle('Effect of Annotator Disagreement on Classifier Performance')
plt.tight_layout(w_pad=6)
plt.show()

# %%
labels = np.arange(1, 7)
# yesterday_test1_mean = [20, 12, 23]
# yesterday_test2_mean = [21, 14, 25]
# today_test1_mean = [18, 10, 12]
# today_test2_mean = [13, 13, 9]

x = labels #np.arange(len(labels))
width = 0.3


# fig, ax = plt.subplots(3, 3, figsize=(8, 8), sharey=True)
fig, ax = plt.subplots(3, 2, figsize=(8, 8), sharey=True)
fig.supxlabel('Number of classes(n) accurately classified')
fig.suptitle('Effect of Annotator Disagreement on Classifier Performance')
fig.supylabel('Percent of samples with n accurate classifications')
# fig = plt.figure(figsize=(15,5))

# (ax1,ax2, ax7), (ax3, ax4, ax8), (ax5, ax6, ax9) = ax

(ax2, ax7), (ax4, ax8), (ax6, ax9) = ax
# ax[0].set_title('si ')
# plt.subplot(121)
# plt.title('RoBERTa Hierarchical', fontsize=13)

# ax1.set_title('RoBERTa Hierarchical\nAll in Agreement')
# b1 = ax1.bar(x, new_ys[0])

# ax1.bar_label(b1, padding=3, fontsize=9, label_type='center')
# # ax.bar_label(rects2, padding=3)

# ax3.set_title('2-way Disagreement')
# b3 = ax3.bar(x, new_ys[1])
# ax3.bar_label(b3, padding=3, fontsize=9, label_type='center')

# ax5.set_title('3-way Disagreement')
# b5 = ax5.bar(x, new_ys[2])
# ax5.bar_label(b5, padding=3, fontsize=9, label_type='center')


ax2.set_title('Without Curriculum Learning\nAll in Agreement')
b2 = ax2.bar(x, new_ys2[0])
ax2.bar_label(b2, padding=3, fontsize=9, label_type='center')


ax4.set_title('2-way Disagreement')
b4 = ax4.bar(x, new_ys2[1])
ax4.bar_label(b4, padding=3, fontsize=9, label_type='center')


ax6.set_title('3-way Disagreement')
b6 = ax6.bar(x, new_ys2[2])
ax6.bar_label(b6, padding=3, fontsize=9, label_type='center')


ax7.set_title('With Curriculum Learning\nAll in Agreement')
b7 = ax7.bar(x, new_ys3[0])

ax7.bar_label(b7, padding=3, fontsize=9, label_type='center')

ax8.set_title('2-way Disagreement')
b8 = ax8.bar(x, new_ys3[1])
ax8.bar_label(b8, padding=3, fontsize=9, label_type='center')


ax9.set_title('3-way Disagreement')
b9 = ax9.bar(x, new_ys3[2])
ax9.bar_label(b9, padding=3, fontsize=9, label_type='center')


# plt.bar(x, new_ys[1], width, label='2-way Disagreement')
# plt.bar(x + width, new_ys[2], width, label='3-way Disagreement')
# plt.ylabel('Accuracy')



# plt.bar(x - width, new_ys[0], width)
# plt.bar(x, new_ys[1], width, label='2-way Disagreement')
# plt.bar(x + width, new_ys[2], width, label='3-way Disagreement')
# plt.ylabel('Accuracy')
# plt.bar(x-width, new_ys[0], width, label='test1', color=np.array((199, 66, 92))/255)



# plt.bar(x+width/2, yesterday_test2_mean, width, label='test2', color=np.array((240, 140, 58))/255)
plt.xticks(x, labels)


# plt.subplot(122)
# plt.title('RoBERTa + Annotator Sentiments', fontsize=13)
# plt.bar(x - width, new_ys2[0], width, label='All in Agreement')
# plt.bar(x, new_ys2[1], width, label='2-way Disagreement')
# plt.bar(x + width, new_ys2[2], width, label='3-way Disagreement')
# plt.xticks(x, labels)


# plt.bar(x-width/2, today_test1_mean, width, hatch='//', color=np.array((199, 66, 92))/255)
# plt.bar(x+width/2, today_test2_mean, width, color=np.array((240, 140, 58))/255)
# plt.xticks([0,1,2], labels, fontsize=15)

# plt.figlegend(loc='upper right', ncol=1, labelspacing=0.5, fontsize=14, bbox_to_anchor=(1.11, 0.9))
# handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='upper left')



plt.tight_layout(w_pad=6)
plt.savefig('barplot-deberta.png',dpi=300)
plt.show()

# %%
new_ys[2]
# Out:
# [0.0, 0.0, 21.21, 36.36, 36.36, 6.06]
